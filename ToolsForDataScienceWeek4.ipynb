# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lachezar Georgiev**
# Data Science Student

# %% [markdown]
# *I am interested in data science I want to work on complex projects involving data. Specifically, I would enjoy if these projects are related to the retail industry.*

# %% [markdown]
# # The code must be executed and produce an output.

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# #Bulleted list
#
#
# -
# -
# -
# -
#
#
#
#
# #Numbered List
# 1.
# 2.
# 3.
# 4.
#
#
#
# #Inserting an image
# ![Mau52.jpg](attachment:Mau52.jpg)

# %% [markdown]
# > vertical line
